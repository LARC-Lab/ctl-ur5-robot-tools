# %% [markdown]
# Test image in matplotlib

# %%
from PIL import Image, ImageFilter

import matplotlib.pyplot as plt
import numpy as np

# %%
img = np.asarray(Image.open('opencv_frame_0.png'))
lum_img = img[:,:,0]
imgplot = plt.imshow(lum_img)

# %%
#edge detection

#image = Image.open(r'opencv_frame_0.png')
#image = image.convert("L")
#image = image.filter(ImageFilter.FIND_EDGES)
#image.save(r'edge_open_CV.png')
